# %%
import numpy as np
import tensorflow as tf
import pickle

# === Load model ===
model = tf.keras.models.load_model('../models/App Predictor Model 4.keras')

# === Load supporting data ===
# Load tokenizer and reverse word index
with open("../data/processed/tokenizer_2.pkl", "rb") as f:
    tokenizer = pickle.load(f)
reverse_word_index = {v: k for k, v in tokenizer.word_index.items()}

# Load test set and meta
test = np.load("../data/processed/test_data_2.npz")
X_test_seq = test['X_seq']
X_test_extra = test['X_extra']
y_test = test['y']

meta = np.load("../data/processed/meta_2.npz")
vocab_size = int(meta['vocab_size'][0])
oov_index = int(meta['oov_index'][0])

# === Run Predictions ===
N_PREDICTIONS = 100
test_indices = np.random.choice(len(X_test_seq), N_PREDICTIONS, replace=False)

print("--- Running Test Predictions ---")

for i in test_indices:
    input_sequence_tokens = X_test_seq[i]
    input_extra_features = X_test_extra[i]
    true_label_token = np.argmax(y_test[i])

    # Decode input sequence
    input_app_names = [reverse_word_index.get(token, '?') for token in input_sequence_tokens if token != 0]
    true_app_name = reverse_word_index.get(true_label_token, 'unknown')

    # Model expects batch dimensions
    input_seq_batch = np.expand_dims(input_sequence_tokens, axis=0)
    input_extra_batch = np.expand_dims(input_extra_features, axis=0)

    # Predict
    prediction_proba = model.predict([input_seq_batch, input_extra_batch], verbose=0)[0]

    # Optional: mask OOV
    if oov_index is not None and oov_index < len(prediction_proba):
        prediction_proba[oov_index] = 0

    # Top-3 predictions
    top_3_indices = np.argsort(prediction_proba)[-3:][::-1]
    top_3_apps = [reverse_word_index.get(idx, 'unknown') for idx in top_3_indices]
    top_3_probs = [prediction_proba[idx] for idx in top_3_indices]

    # Output
    print(f"{' | '.join(input_app_names)}")
    print("PREDICTIONS:")
    for app, prob in zip(top_3_apps, top_3_probs):
        print(f"   - {app:<25} (Confidence: {prob:.2%})")
    print(f"NEXT APP: {true_app_name}")
    print("="*60)
# Out:
# --- Running Test Predictions ---
# telegram | contacts | telegram | contacts | telegram | contacts | telegram | contacts | telegram | contacts | telegram | gmail | telegram | instagram | gmail
# PREDICTIONS:
#    - instagram                 (Confidence: 61.49%)
#    - telegram                  (Confidence: 29.60%)
#    - contacts                  (Confidence: 3.40%)
# NEXT APP: telegram
# ============================================================
# <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.46%)
#    - gmail                     (Confidence: 0.14%)
#    - settings                  (Confidence: 0.08%)
# NEXT APP: google
# ============================================================
# <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV>
# PREDICTIONS:
#    - twitter                   (Confidence: 98.81%)
#    - google                    (Confidence: 0.48%)
#    - gmail                     (Confidence: 0.28%)
# NEXT APP: twitter
# ============================================================
# facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | camera | twitter | camera | twitter | camera | twitter | camera
# PREDICTIONS:
#    - twitter                   (Confidence: 96.46%)
#    - facebook                  (Confidence: 0.84%)
#    - telegram                  (Confidence: 0.49%)
# NEXT APP: twitter
# ============================================================
# <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.79%)
#    - gmail                     (Confidence: 0.05%)
#    - messages                  (Confidence: 0.04%)
# NEXT APP: google
# ============================================================
# phone | messaging | phone | contacts | phone | contacts | messaging | contacts | messaging | phone | messaging | phone | contacts | phone | contacts
# PREDICTIONS:
#    - phone                     (Confidence: 80.70%)
#    - messaging                 (Confidence: 18.98%)
#    - gmail                     (Confidence: 0.09%)
# NEXT APP: messaging
# ============================================================
# instagram | telegram | twitter | instagram | telegram | instagram | telegram | instagram | telegram | <OOV> | telegram | <OOV> | telegram | maps | telegram
# PREDICTIONS:
#    - maps                      (Confidence: 63.74%)
#    - instagram                 (Confidence: 23.60%)
#    - twitter                   (Confidence: 4.12%)
# NEXT APP: maps
# ============================================================
# <OOV> | swagbucks | <OOV> | swagbucks | <OOV> | messages | <OOV> | swagbucks | messages | <OOV> | messages | google | messages | google | messages
# PREDICTIONS:
#    - google                    (Confidence: 97.39%)
#    - gmail                     (Confidence: 0.86%)
#    - swagbucks                 (Confidence: 0.68%)
# NEXT APP: google
# ============================================================
# <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | gmail | gmail | facebook | <OOV> | facebook | <OOV> | facebook | <OOV>
# PREDICTIONS:
#    - facebook                  (Confidence: 96.12%)
#    - gmail                     (Confidence: 1.93%)
#    - google                    (Confidence: 0.45%)
# NEXT APP: facebook
# ============================================================
# google | gmail | google | youtube | telegram | youtube | google | phone | <OOV> | google | telegram | gmail | google | hangouts | hangouts
# PREDICTIONS:
#    - google                    (Confidence: 68.26%)
#    - telegram                  (Confidence: 14.24%)
#    - gmail                     (Confidence: 14.18%)
# NEXT APP: google
# ============================================================
# <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | google | <OOV> | gmail | <OOV> | <OOV> | gmail | <OOV>
# PREDICTIONS:
#    - gmail                     (Confidence: 58.60%)
#    - google                    (Confidence: 13.69%)
#    - facebook                  (Confidence: 5.23%)
# NEXT APP: pinterest
# ============================================================
# hangouts | <OOV> | <OOV> | hangouts | <OOV> | hangouts | google | hangouts | google | twitter | google | twitter | google | twitter | google
# PREDICTIONS:
#    - twitter                   (Confidence: 79.62%)
#    - hangouts                  (Confidence: 9.25%)
#    - instagram                 (Confidence: 4.81%)
# NEXT APP: hangouts
# ============================================================
# google | telegram | google | telegram | google | <OOV> | google | <OOV> | google | <OOV> | google | facebook | google | facebook | telegram
# PREDICTIONS:
#    - facebook                  (Confidence: 76.57%)
#    - google                    (Confidence: 22.34%)
#    - instagram                 (Confidence: 0.30%)
# NEXT APP: facebook
# ============================================================
# hulu | <OOV> | hulu | metrozone | phone | metrozone | phone | metrozone | hulu | gmail | youtube | metrozone | hulu | metrozone | metrozone
# PREDICTIONS:
#    - metrozone                 (Confidence: 49.96%)
#    - phone                     (Confidence: 17.30%)
#    - hulu                      (Confidence: 12.57%)
# NEXT APP: phone
# ============================================================
# <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | google | facebook | google
# PREDICTIONS:
#    - facebook                  (Confidence: 99.02%)
#    - instagram                 (Confidence: 0.26%)
#    - youtube                   (Confidence: 0.14%)
# NEXT APP: facebook
# ============================================================
# pinterest | <OOV> | ebay | <OOV> | contacts | contacts | messages | messages | <OOV> | <OOV> | <OOV> | <OOV> | messages | contacts | messages
# PREDICTIONS:
#    - contacts                  (Confidence: 99.50%)
#    - calculator                (Confidence: 0.19%)
#    - gmail                     (Confidence: 0.06%)
# NEXT APP: contacts
# ============================================================
# <OOV> | google | <OOV> | <OOV> | twitter | <OOV> | twitter | google | google | instagram | instagram | <OOV> | instagram | <OOV> | instagram
# PREDICTIONS:
#    - google                    (Confidence: 83.21%)
#    - twitter                   (Confidence: 5.71%)
#    - gmail                     (Confidence: 4.42%)
# NEXT APP: google
# ============================================================
# <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | youtube | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV>
# PREDICTIONS:
#    - facebook                  (Confidence: 20.25%)
#    - google                    (Confidence: 16.20%)
#    - youtube                   (Confidence: 15.73%)
# NEXT APP: google
# ============================================================
# google | google | gmail | google | gmail | google | gmail | google | gmail | google | gmail | google | gmail | twitter | gmail
# PREDICTIONS:
#    - google                    (Confidence: 49.71%)
#    - twitter                   (Confidence: 44.06%)
#    - instagram                 (Confidence: 1.32%)
# NEXT APP: google
# ============================================================
# phone | contacts | phone | contacts | phone | contacts | phone | contacts | phone | contacts | phone | contacts | phone | contacts | phone
# PREDICTIONS:
#    - contacts                  (Confidence: 98.72%)
#    - messaging                 (Confidence: 1.08%)
#    - gmail                     (Confidence: 0.09%)
# NEXT APP: contacts
# ============================================================
# <OOV> | youtube | <OOV> | youtube | <OOV> | youtube | <OOV> | youtube | <OOV> | youtube | <OOV> | youtube | <OOV> | youtube | <OOV>
# PREDICTIONS:
#    - youtube                   (Confidence: 97.74%)
#    - google                    (Confidence: 0.50%)
#    - gmail                     (Confidence: 0.35%)
# NEXT APP: youtube
# ============================================================
# instagram | telegram | instagram | telegram | contacts | telegram | contacts | telegram | instagram | telegram | <OOV> | telegram | instagram | telegram | instagram
# PREDICTIONS:
#    - telegram                  (Confidence: 97.78%)
#    - contacts                  (Confidence: 1.17%)
#    - facebook                  (Confidence: 0.28%)
# NEXT APP: telegram
# ============================================================
# <OOV> | reddit | <OOV> | reddit | <OOV> | reddit | <OOV> | reddit | <OOV> | reddit | <OOV> | reddit | <OOV> | reddit | <OOV>
# PREDICTIONS:
#    - reddit                    (Confidence: 99.80%)
#    - lucktastic                (Confidence: 0.04%)
#    - snapchat                  (Confidence: 0.03%)
# NEXT APP: reddit
# ============================================================
# contacts | <OOV> | contacts | google | <OOV> | google | google | contacts | <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV>
# PREDICTIONS:
#    - contacts                  (Confidence: 75.48%)
#    - google                    (Confidence: 10.93%)
#    - facebook                  (Confidence: 3.66%)
# NEXT APP: contacts
# ============================================================
# phone | messaging | phone | messaging | phone | messaging | phone | messaging | phone | messaging | phone | messaging | gmail | messaging | phone
# PREDICTIONS:
#    - messaging                 (Confidence: 56.55%)
#    - gmail                     (Confidence: 15.23%)
#    - contacts                  (Confidence: 13.90%)
# NEXT APP: contacts
# ============================================================
# <OOV> | hangouts | hangouts | <OOV> | facebook | hangouts | hangouts | swagbucks | facebook | hangouts | hangouts | facebook | hangouts | <OOV> | hangouts
# PREDICTIONS:
#    - hangouts                  (Confidence: 32.46%)
#    - facebook                  (Confidence: 21.82%)
#    - instagram                 (Confidence: 16.12%)
# NEXT APP: hangouts
# ============================================================
# messages | contacts | messages | instagram | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | walmart | <OOV> | instagram | instagram
# PREDICTIONS:
#    - instagram                 (Confidence: 62.70%)
#    - messages                  (Confidence: 13.15%)
#    - camera                    (Confidence: 10.60%)
# NEXT APP: instagram
# ============================================================
# slidejoy | <OOV> | slidejoy | messages | slidejoy | messages | slidejoy | messages | slidejoy | messages | maps | gmail | <OOV> | gmail | <OOV>
# PREDICTIONS:
#    - gmail                     (Confidence: 90.24%)
#    - messages                  (Confidence: 4.07%)
#    - facebook                  (Confidence: 1.99%)
# NEXT APP: gmail
# ============================================================
# facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | surveycow | surveycow | surveycow
# PREDICTIONS:
#    - surveycow                 (Confidence: 89.63%)
#    - facebook                  (Confidence: 6.57%)
#    - contacts                  (Confidence: 1.21%)
# NEXT APP: surveycow
# ============================================================
# youtube | <OOV> | facebook | gmail | messages | <OOV> | messages | <OOV> | messages | <OOV> | messages | <OOV> | <OOV> | <OOV> | <OOV>
# PREDICTIONS:
#    - messages                  (Confidence: 26.58%)
#    - gmail                     (Confidence: 23.22%)
#    - facebook                  (Confidence: 21.50%)
# NEXT APP: camera
# ============================================================
# slidejoy | settings | <OOV> | slidejoy | slidejoy | slidejoy | <OOV> | facebook | <OOV> | facebook | phone | facebook | phone | slidejoy | phone
# PREDICTIONS:
#    - slidejoy                  (Confidence: 98.92%)
#    - facebook                  (Confidence: 0.39%)
#    - contacts                  (Confidence: 0.13%)
# NEXT APP: slidejoy
# ============================================================
# contacts | <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | surveycow | surveycow | facebook | surveycow | surveycow | <OOV>
# PREDICTIONS:
#    - surveycow                 (Confidence: 92.38%)
#    - facebook                  (Confidence: 3.65%)
#    - google                    (Confidence: 1.61%)
# NEXT APP: surveycow
# ============================================================
# messages | <OOV> | messages | <OOV> | messages | <OOV> | messages | <OOV> | instagram | gmail | <OOV> | messages | messages | instagram | messages
# PREDICTIONS:
#    - instagram                 (Confidence: 73.26%)
#    - gmail                     (Confidence: 9.27%)
#    - contacts                  (Confidence: 5.36%)
# NEXT APP: instagram
# ============================================================
# maps | messages | maps | messages | maps | messages | maps | messages | maps | messages | maps | messages | maps | messages | maps
# PREDICTIONS:
#    - messages                  (Confidence: 99.36%)
#    - google                    (Confidence: 0.22%)
#    - maps                      (Confidence: 0.08%)
# NEXT APP: messages
# ============================================================
# <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.62%)
#    - facebook                  (Confidence: 0.09%)
#    - messages                  (Confidence: 0.06%)
# NEXT APP: google
# ============================================================
# facebook | settings | google | settings | facebook | facebook | settings | facebook | instagram | facebook | facebook | facebook | facebook | facebook | google
# PREDICTIONS:
#    - facebook                  (Confidence: 75.87%)
#    - instagram                 (Confidence: 8.62%)
#    - youtube                   (Confidence: 4.86%)
# NEXT APP: facebook
# ============================================================
# gmail | messages | instagram | messages | instagram | gmail | instagram | gmail | instagram | gmail | instagram | gmail | instagram | messages | instagram
# PREDICTIONS:
#    - messages                  (Confidence: 93.47%)
#    - gmail                     (Confidence: 4.88%)
#    - contacts                  (Confidence: 0.45%)
# NEXT APP: messages
# ============================================================
# <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | gmail | <OOV> | gmail | <OOV>
# PREDICTIONS:
#    - gmail                     (Confidence: 98.81%)
#    - google                    (Confidence: 0.30%)
#    - maps                      (Confidence: 0.20%)
# NEXT APP: gmail
# ============================================================
# instagram | clock | instagram | clock | <OOV> | clock | instagram | clock | instagram | clock | google | clock | google | clock | instagram
# PREDICTIONS:
#    - clock                     (Confidence: 58.37%)
#    - google                    (Confidence: 23.70%)
#    - facebook                  (Confidence: 9.39%)
# NEXT APP: clock
# ============================================================
# <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | facebook
# PREDICTIONS:
#    - twitter                   (Confidence: 34.36%)
#    - facebook                  (Confidence: 24.19%)
#    - instagram                 (Confidence: 6.56%)
# NEXT APP: facebook
# ============================================================
# <OOV> | reddit | <OOV> | reddit | <OOV> | reddit | reddit | facebook | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook
# PREDICTIONS:
#    - facebook                  (Confidence: 45.37%)
#    - reddit                    (Confidence: 15.00%)
#    - google                    (Confidence: 8.88%)
# NEXT APP: google
# ============================================================
# google | twitter | google | twitter | google | twitter | google | twitter | google | twitter | google | twitter | google | twitter | google
# PREDICTIONS:
#    - twitter                   (Confidence: 98.87%)
#    - hangouts                  (Confidence: 0.24%)
#    - instagram                 (Confidence: 0.23%)
# NEXT APP: twitter
# ============================================================
# slidejoy | <OOV> | slidejoy | <OOV> | slidejoy | <OOV> | slidejoy | <OOV> | slidejoy | <OOV> | slidejoy | <OOV> | slidejoy | <OOV> | slidejoy
# PREDICTIONS:
#    - slidejoy                  (Confidence: 97.75%)
#    - facebook                  (Confidence: 0.50%)
#    - messages                  (Confidence: 0.48%)
# NEXT APP: slidejoy
# ============================================================
# calendar | messages | calendar | messages | calendar | messages | calendar | messages | calendar | messages | <OOV> | messages | <OOV> | messages | <OOV>
# PREDICTIONS:
#    - messages                  (Confidence: 97.75%)
#    - calendar                  (Confidence: 0.73%)
#    - facebook                  (Confidence: 0.43%)
# NEXT APP: messages
# ============================================================
# gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | camera | gmail | camera | gmail | camera | gmail
# PREDICTIONS:
#    - camera                    (Confidence: 97.95%)
#    - facebook                  (Confidence: 0.64%)
#    - calculator                (Confidence: 0.24%)
# NEXT APP: camera
# ============================================================
# gmail | reddit | gmail | reddit | <OOV> | reddit | snapchat | reddit | snapchat | reddit | reddit | snapchat | <OOV> | <OOV> | <OOV>
# PREDICTIONS:
#    - snapchat                  (Confidence: 33.22%)
#    - reddit                    (Confidence: 23.92%)
#    - gmail                     (Confidence: 16.45%)
# NEXT APP: google
# ============================================================
# twitter | twitter | twitter | twitter | twitter | telegram | telegram | twitter | maps | twitter | twitter | telegram | twitter | telegram | twitter
# PREDICTIONS:
#    - telegram                  (Confidence: 96.84%)
#    - instagram                 (Confidence: 1.39%)
#    - google                    (Confidence: 0.49%)
# NEXT APP: telegram
# ============================================================
# messaging | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | phone | <OOV> | phone | <OOV> | phone | gmail | maps | phone | <OOV>
# PREDICTIONS:
#    - phone                     (Confidence: 87.37%)
#    - gmail                     (Confidence: 8.15%)
#    - messaging                 (Confidence: 1.99%)
# NEXT APP: phone
# ============================================================
# instagram | facebook | instagram | <OOV> | <OOV> | instagram | <OOV> | instagram | facebook | discord | facebook | discord | facebook | discord | facebook
# PREDICTIONS:
#    - discord                   (Confidence: 78.31%)
#    - instagram                 (Confidence: 7.40%)
#    - google                    (Confidence: 3.57%)
# NEXT APP: facebook
# ============================================================
# settings | telegram | youtube | telegram | youtube | youtube | telegram | youtube | telegram | youtube | telegram | youtube | youtube | telegram | youtube
# PREDICTIONS:
#    - telegram                  (Confidence: 60.60%)
#    - youtube                   (Confidence: 33.49%)
#    - settings                  (Confidence: 3.02%)
# NEXT APP: youtube
# ============================================================
# <OOV> | messaging | <OOV> | messaging | <OOV> | messaging | <OOV> | messaging | <OOV> | gmail | <OOV> | messaging | facebook | phone | facebook
# PREDICTIONS:
#    - phone                     (Confidence: 89.25%)
#    - messaging                 (Confidence: 8.14%)
#    - gmail                     (Confidence: 0.98%)
# NEXT APP: phone
# ============================================================
# facebook | <OOV> | facebook | facebook | <OOV> | facebook | instagram | facebook | instagram | facebook | instagram | facebook | instagram | facebook | instagram
# PREDICTIONS:
#    - facebook                  (Confidence: 99.23%)
#    - google                    (Confidence: 0.14%)
#    - messages                  (Confidence: 0.09%)
# NEXT APP: facebook
# ============================================================
# slidejoy | <OOV> | slidejoy | <OOV> | gmail | <OOV> | maps | <OOV> | maps | <OOV> | maps | <OOV> | facebook | gmail | facebook
# PREDICTIONS:
#    - gmail                     (Confidence: 95.27%)
#    - maps                      (Confidence: 3.11%)
#    - slidejoy                  (Confidence: 0.63%)
# NEXT APP: gmail
# ============================================================
# telegram | google | telegram | google | telegram | google | telegram | google | telegram | google | telegram | google | telegram | google | telegram
# PREDICTIONS:
#    - google                    (Confidence: 99.89%)
#    - gmail                     (Confidence: 0.03%)
#    - hangouts                  (Confidence: 0.02%)
# NEXT APP: google
# ============================================================
# youtube | hulu | s’more | s’more | s’more | hulu | pinterest | hulu | youtube | hulu | twitter | <OOV> | twitter | hulu | twitter
# PREDICTIONS:
#    - hulu                      (Confidence: 81.71%)
#    - youtube                   (Confidence: 6.29%)
#    - s’more                    (Confidence: 3.47%)
# NEXT APP: youtube
# ============================================================
# <OOV> | facebook | gmail | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | <OOV> | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 38.85%)
#    - facebook                  (Confidence: 21.41%)
#    - gmail                     (Confidence: 17.81%)
# NEXT APP: google
# ============================================================
# contacts | phone | contacts | phone | contacts | phone | metrozone | phone | metrozone | phone | metrozone | phone | metrozone | phone | metrozone
# PREDICTIONS:
#    - phone                     (Confidence: 98.30%)
#    - lucktastic                (Confidence: 0.70%)
#    - messaging                 (Confidence: 0.28%)
# NEXT APP: phone
# ============================================================
# <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV>
# PREDICTIONS:
#    - gmail                     (Confidence: 99.40%)
#    - google                    (Confidence: 0.11%)
#    - maps                      (Confidence: 0.09%)
# NEXT APP: gmail
# ============================================================
# contacts | messages | camera | messages | messages | messages | messages | messages | messages | <OOV> | messages | contacts | messages | contacts | maps
# PREDICTIONS:
#    - contacts                  (Confidence: 41.49%)
#    - messages                  (Confidence: 19.93%)
#    - maps                      (Confidence: 17.39%)
# NEXT APP: maps
# ============================================================
# google | instagram | google | instagram | google | instagram | google | instagram | google | instagram | google | instagram | google | instagram | google
# PREDICTIONS:
#    - instagram                 (Confidence: 98.74%)
#    - telegram                  (Confidence: 0.69%)
#    - facebook                  (Confidence: 0.13%)
# NEXT APP: instagram
# ============================================================
# instagram | <OOV> | instagram | google | instagram | <OOV> | <OOV> | instagram | messages | instagram | messages | calendar | google | maps | google
# PREDICTIONS:
#    - google                    (Confidence: 25.72%)
#    - maps                      (Confidence: 23.80%)
#    - messages                  (Confidence: 9.86%)
# NEXT APP: instagram
# ============================================================
# messages | slidejoy | messages | slidejoy | <OOV> | slidejoy | slidejoy | messages | slidejoy | messages | slidejoy | messages | slidejoy | <OOV> | slidejoy
# PREDICTIONS:
#    - messages                  (Confidence: 95.34%)
#    - facebook                  (Confidence: 3.86%)
#    - instagram                 (Confidence: 0.33%)
# NEXT APP: messages
# ============================================================
# <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV>
# PREDICTIONS:
#    - contacts                  (Confidence: 99.54%)
#    - gmail                     (Confidence: 0.08%)
#    - messaging                 (Confidence: 0.08%)
# NEXT APP: contacts
# ============================================================
# telegram | twitter | <OOV> | <OOV> | instagram | instagram | twitter | twitter | telegram | twitter | twitter | maps | twitter | maps | twitter
# PREDICTIONS:
#    - twitter                   (Confidence: 41.42%)
#    - telegram                  (Confidence: 18.09%)
#    - instagram                 (Confidence: 14.02%)
# NEXT APP: twitter
# ============================================================
# camera | facebook | contacts | s’more | s’more | contacts | s’more | <OOV> | s’more | s’more | s’more | facebook | s’more | s’more | facebook
# PREDICTIONS:
#    - s’more                    (Confidence: 59.41%)
#    - facebook                  (Confidence: 9.58%)
#    - textnow                   (Confidence: 8.04%)
# NEXT APP: s’more
# ============================================================
# google | <OOV> | google | <OOV> | google | instagram | google | instagram | google | instagram | google | instagram | google | instagram | google
# PREDICTIONS:
#    - instagram                 (Confidence: 98.24%)
#    - telegram                  (Confidence: 0.85%)
#    - facebook                  (Confidence: 0.23%)
# NEXT APP: instagram
# ============================================================
# messages | camera | settings | settings | youtube | discord | facebook | discord | gmail | discord | gmail | discord | camera | gmail | discord
# PREDICTIONS:
#    - gmail                     (Confidence: 40.48%)
#    - discord                   (Confidence: 17.06%)
#    - facebook                  (Confidence: 6.28%)
# NEXT APP: settings
# ============================================================
# gmail | maps | <OOV> | <OOV> | facebook | google | <OOV> | google | facebook | <OOV> | facebook | google | <OOV> | facebook | <OOV>
# PREDICTIONS:
#    - facebook                  (Confidence: 81.24%)
#    - google                    (Confidence: 13.76%)
#    - gmail                     (Confidence: 2.22%)
# NEXT APP: google
# ============================================================
# <OOV> | messaging | <OOV> | messaging | <OOV> | messaging | <OOV> | messaging | <OOV> | messaging | <OOV> | messaging | <OOV> | messaging | <OOV>
# PREDICTIONS:
#    - messaging                 (Confidence: 98.53%)
#    - google                    (Confidence: 0.47%)
#    - facebook                  (Confidence: 0.35%)
# NEXT APP: messaging
# ============================================================
# <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV>
# PREDICTIONS:
#    - gmail                     (Confidence: 99.34%)
#    - google                    (Confidence: 0.13%)
#    - maps                      (Confidence: 0.11%)
# NEXT APP: gmail
# ============================================================
# <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.78%)
#    - gmail                     (Confidence: 0.06%)
#    - messages                  (Confidence: 0.03%)
# NEXT APP: google
# ============================================================
# <OOV> | youtube | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | facebook | <OOV> | youtube | youtube | facebook | <OOV>
# PREDICTIONS:
#    - facebook                  (Confidence: 45.68%)
#    - youtube                   (Confidence: 24.52%)
#    - google                    (Confidence: 17.54%)
# NEXT APP: facebook
# ============================================================
# slidejoy | facebook | slidejoy | facebook | slidejoy | facebook | slidejoy | facebook | slidejoy | slidejoy | slidejoy | facebook | slidejoy | facebook | slidejoy
# PREDICTIONS:
#    - facebook                  (Confidence: 99.83%)
#    - messages                  (Confidence: 0.11%)
#    - gmail                     (Confidence: 0.01%)
# NEXT APP: facebook
# ============================================================
# <OOV> | facebook | camera | messages | camera | messages | <OOV> | messages | camera | <OOV> | camera | <OOV> | facebook | camera | <OOV>
# PREDICTIONS:
#    - camera                    (Confidence: 76.18%)
#    - messages                  (Confidence: 8.34%)
#    - facebook                  (Confidence: 7.41%)
# NEXT APP: camera
# ============================================================
# <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.81%)
#    - gmail                     (Confidence: 0.04%)
#    - messages                  (Confidence: 0.03%)
# NEXT APP: google
# ============================================================
# messages | instagram | messages | instagram | messages | instagram | instagram | instagram | google | contacts | contacts | contacts | contacts | contacts | contacts
# PREDICTIONS:
#    - contacts                  (Confidence: 73.75%)
#    - messages                  (Confidence: 14.01%)
#    - instagram                 (Confidence: 5.60%)
# NEXT APP: contacts
# ============================================================
# calendar | instagram | calendar | instagram | calendar | instagram | calendar | instagram | calendar | instagram | <OOV> | gmail | <OOV> | facebook | <OOV>
# PREDICTIONS:
#    - facebook                  (Confidence: 90.90%)
#    - gmail                     (Confidence: 3.91%)
#    - instagram                 (Confidence: 2.43%)
# NEXT APP: facebook
# ============================================================
# facebook | messages | facebook | messages | facebook | messages | facebook | messages | facebook | messages | facebook | messages | facebook | messages | facebook
# PREDICTIONS:
#    - messages                  (Confidence: 99.36%)
#    - gmail                     (Confidence: 0.16%)
#    - slidejoy                  (Confidence: 0.16%)
# NEXT APP: messages
# ============================================================
# <OOV> | <OOV> | <OOV> | <OOV> | settings | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | gmail | <OOV> | gmail | messages
# PREDICTIONS:
#    - messages                  (Confidence: 43.44%)
#    - gmail                     (Confidence: 27.89%)
#    - google                    (Confidence: 5.25%)
# NEXT APP: messages
# ============================================================
# snapchat | snapchat | reddit | snapchat | reddit | snapchat | reddit | snapchat | reddit | snapchat | reddit | snapchat | gmail | gmail | facebook
# PREDICTIONS:
#    - snapchat                  (Confidence: 49.27%)
#    - reddit                    (Confidence: 19.05%)
#    - gmail                     (Confidence: 16.96%)
# NEXT APP: snapchat
# ============================================================
# facebook | <OOV> | facebook | <OOV> | facebook | settings | <OOV> | <OOV> | discord | discord | settings | camera | <OOV> | camera | <OOV>
# PREDICTIONS:
#    - camera                    (Confidence: 96.45%)
#    - messages                  (Confidence: 0.93%)
#    - discord                   (Confidence: 0.77%)
# NEXT APP: camera
# ============================================================
# twitter | snapchat | youtube | instagram | youtube | instagram | youtube | instagram | youtube | instagram | snapchat | youtube | snapchat | youtube | snapchat
# PREDICTIONS:
#    - youtube                   (Confidence: 86.53%)
#    - instagram                 (Confidence: 6.61%)
#    - twitter                   (Confidence: 2.49%)
# NEXT APP: youtube
# ============================================================
# snapchat | youtube | snapchat | youtube | snapchat | youtube | snapchat | youtube | snapchat | youtube | snapchat | youtube | snapchat | youtube | snapchat
# PREDICTIONS:
#    - youtube                   (Confidence: 96.70%)
#    - facebook                  (Confidence: 0.75%)
#    - google                    (Confidence: 0.55%)
# NEXT APP: youtube
# ============================================================
# settings | settings | google | settings | google | <OOV> | instagram | google | instagram | google | google | google | instagram | google | instagram
# PREDICTIONS:
#    - google                    (Confidence: 77.68%)
#    - instagram                 (Confidence: 11.29%)
#    - facebook                  (Confidence: 2.91%)
# NEXT APP: google
# ============================================================
# google | telegram | google | google | telegram | google | telegram | google | telegram | google | telegram | google | telegram | google | twitter
# PREDICTIONS:
#    - google                    (Confidence: 95.29%)
#    - telegram                  (Confidence: 4.45%)
#    - messages                  (Confidence: 0.14%)
# NEXT APP: google
# ============================================================
# <OOV> | settings | <OOV> | settings | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.68%)
#    - settings                  (Confidence: 0.07%)
#    - gmail                     (Confidence: 0.06%)
# NEXT APP: google
# ============================================================
# google | <OOV> | google | <OOV> | google | instagram | google | instagram | google | instagram | google | instagram | google | instagram | google
# PREDICTIONS:
#    - google                    (Confidence: 57.32%)
#    - instagram                 (Confidence: 15.97%)
#    - gmail                     (Confidence: 5.76%)
# NEXT APP: pinterest
# ============================================================
# telegram | <OOV> | telegram | <OOV> | telegram | <OOV> | telegram | telegram | telegram | telegram | telegram | telegram | telegram | settings | google
# PREDICTIONS:
#    - telegram                  (Confidence: 37.62%)
#    - settings                  (Confidence: 22.46%)
#    - google                    (Confidence: 11.53%)
# NEXT APP: telegram
# ============================================================
# <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.80%)
#    - gmail                     (Confidence: 0.04%)
#    - messages                  (Confidence: 0.03%)
# NEXT APP: google
# ============================================================
# gmail | instagram | gmail | clock | clock | clock | <OOV> | twitter | instagram | <OOV> | maps | google | <OOV> | google | instagram
# PREDICTIONS:
#    - instagram                 (Confidence: 27.42%)
#    - google                    (Confidence: 15.37%)
#    - clock                     (Confidence: 14.08%)
# NEXT APP: clock
# ============================================================
# <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV>
# PREDICTIONS:
#    - facebook                  (Confidence: 16.52%)
#    - google                    (Confidence: 13.37%)
#    - gmail                     (Confidence: 9.16%)
# NEXT APP: settings
# ============================================================
# google | <OOV> | <OOV> | telegram | <OOV> | telegram | facebook | <OOV> | <OOV> | <OOV> | <OOV> | telegram | <OOV> | <OOV> | <OOV>
# PREDICTIONS:
#    - telegram                  (Confidence: 47.68%)
#    - google                    (Confidence: 13.84%)
#    - facebook                  (Confidence: 10.23%)
# NEXT APP: facebook
# ============================================================
# contacts | <OOV> | gmail | <OOV> | youtube | gmail | google | settings | gmail | metrozone | gmail | metrozone | metrozone | metrozone | gmail
# PREDICTIONS:
#    - metrozone                 (Confidence: 60.88%)
#    - gmail                     (Confidence: 17.58%)
#    - google                    (Confidence: 6.06%)
# NEXT APP: metrozone
# ============================================================
# instagram | imo | instagram | imo | calendar | imo | telegram | imo | telegram | imo | telegram | imo | telegram | imo | telegram
# PREDICTIONS:
#    - imo                       (Confidence: 99.72%)
#    - google                    (Confidence: 0.07%)
#    - instagram                 (Confidence: 0.06%)
# NEXT APP: imo
# ============================================================
# gmail | <OOV> | <OOV> | messages | settings | <OOV> | messages | <OOV> | messages | phone | messages | hangouts | messages | hangouts | <OOV>
# PREDICTIONS:
#    - hangouts                  (Confidence: 57.16%)
#    - messages                  (Confidence: 19.56%)
#    - facebook                  (Confidence: 4.89%)
# NEXT APP: messages
# ============================================================
# instagram | facebook | instagram | facebook | instagram | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV>
# PREDICTIONS:
#    - facebook                  (Confidence: 98.23%)
#    - instagram                 (Confidence: 0.49%)
#    - google                    (Confidence: 0.46%)
# NEXT APP: facebook
# ============================================================
# telegram | calendar | telegram | google | telegram | instagram | calendar | instagram | telegram | <OOV> | telegram | <OOV> | telegram | <OOV> | facebook
# PREDICTIONS:
#    - telegram                  (Confidence: 35.27%)
#    - facebook                  (Confidence: 16.25%)
#    - instagram                 (Confidence: 13.56%)
# NEXT APP: instagram
# ============================================================
# telegram | google | telegram | google | telegram | google | telegram | google | telegram | google | telegram | google | telegram | google | telegram
# PREDICTIONS:
#    - google                    (Confidence: 99.89%)
#    - gmail                     (Confidence: 0.03%)
#    - hangouts                  (Confidence: 0.02%)
# NEXT APP: google
# ============================================================
# google | gmail | <OOV> | gmail | facebook | <OOV> | facebook | <OOV> | messaging | facebook | gmail | facebook | google | maps | <OOV>
# PREDICTIONS:
#    - facebook                  (Confidence: 25.61%)
#    - gmail                     (Confidence: 24.24%)
#    - maps                      (Confidence: 17.28%)
# NEXT APP: youtube
# ============================================================
# instagram | google | google | <OOV> | google | google | instagram | google | instagram | google | <OOV> | facebook | <OOV> | facebook | google
# PREDICTIONS:
#    - facebook                  (Confidence: 73.70%)
#    - instagram                 (Confidence: 16.14%)
#    - twitter                   (Confidence: 2.42%)
# NEXT APP: instagram
# ============================================================

# %%
# Calculate how many times the true label is in the top-3 predictions
from tqdm import tqdm

top3_correct = 0
top1_correct = 0
N = min(len(X_test_seq), 10000)
mistakes = []

for i in tqdm(range(N), desc="Evaluating top-3 accuracy"):
    input_sequence_tokens = X_test_seq[i]
    input_extra_features = X_test_extra[i]
    true_label_token = np.argmax(y_test[i])

    input_seq_batch = np.expand_dims(input_sequence_tokens, axis=0)
    input_extra_batch = np.expand_dims(input_extra_features, axis=0)

    prediction_proba = model.predict([input_seq_batch, input_extra_batch], verbose=0)[0]
    
    if oov_index is not None and oov_index < len(prediction_proba):
        prediction_proba[oov_index] = 0

    top_3_indices = np.argsort(prediction_proba)[-3:][::-1]
    if true_label_token in top_3_indices:
        top3_correct += 1
    else:
        # Save mistake info
        input_app_names = [reverse_word_index.get(token, '?') for token in input_sequence_tokens if token != 0]
        true_app_name = reverse_word_index.get(true_label_token, 'unknown')
        top_3_apps = [reverse_word_index.get(idx, 'unknown') for idx in top_3_indices]
        top_3_probs = [prediction_proba[idx] for idx in top_3_indices]
        mistake_str = (
            f"INPUT: {' | '.join(input_app_names)}\n"
            f"TRUE NEXT APP: {true_app_name}\n"
            f"PREDICTIONS:\n"
            + "\n".join([f"   - {app:<25} (Confidence: {prob:.2%})" for app, prob in zip(top_3_apps, top_3_probs)])
            + "\n" + "="*60 + "\n"
        )
        mistakes.append(mistake_str)
    if true_label_token == top_3_indices[0]:
        top1_correct += 1

top3_accuracy = top3_correct / N
top1_accuracy = top1_correct / N
print(f"Top-3 accuracy: {top3_accuracy:.2%} ({top3_correct}/{N})")
print(f"Top-1 accuracy: {top1_accuracy:.2%} ({top1_correct}/{N})")

# Save mistakes to file.txt
with open("mistakes.txt", "w", encoding="utf-8") as f:
    for mistake in mistakes:
        f.write(mistake)
# Out:
# Evaluating top-3 accuracy: 100%|██████████| 10000/10000 [04:50<00:00, 34.37it/s]
# Top-3 accuracy: 89.03% (8903/10000)
# Top-1 accuracy: 74.36% (7436/10000)
