# %%
import numpy as np
import tensorflow as tf
import pickle

# === Load model ===
model = tf.keras.models.load_model('../models/App Predictor Model 2.keras')

# === Load supporting data ===
# Load tokenizer and reverse word index
with open("../data/processed/tokenizer.pkl", "rb") as f:
    tokenizer = pickle.load(f)
reverse_word_index = {v: k for k, v in tokenizer.word_index.items()}

# Load test set and meta
test = np.load("../data/processed/test_data.npz")
X_test_seq = test['X_seq']
X_test_extra = test['X_extra']
y_test = test['y']

meta = np.load("../data/processed/meta.npz")
vocab_size = int(meta['vocab_size'][0])
oov_index = int(meta['oov_index'][0])

# === Run Predictions ===
N_PREDICTIONS = 100
test_indices = np.random.choice(len(X_test_seq), N_PREDICTIONS, replace=False)

print("--- Running Test Predictions ---")

for i in test_indices:
    input_sequence_tokens = X_test_seq[i]
    input_extra_features = X_test_extra[i]
    true_label_token = np.argmax(y_test[i])

    # Decode input sequence
    input_app_names = [reverse_word_index.get(token, '?') for token in input_sequence_tokens if token != 0]
    true_app_name = reverse_word_index.get(true_label_token, 'unknown')

    # Model expects batch dimensions
    input_seq_batch = np.expand_dims(input_sequence_tokens, axis=0)
    input_extra_batch = np.expand_dims(input_extra_features, axis=0)

    # Predict
    prediction_proba = model.predict([input_seq_batch, input_extra_batch], verbose=0)[0]

    # Optional: mask OOV
    if oov_index is not None and oov_index < len(prediction_proba):
        prediction_proba[oov_index] = 0

    # Top-3 predictions
    top_3_indices = np.argsort(prediction_proba)[-3:][::-1]
    top_3_apps = [reverse_word_index.get(idx, 'unknown') for idx in top_3_indices]
    top_3_probs = [prediction_proba[idx] for idx in top_3_indices]

    # Output
    print(f"{' | '.join(input_app_names)}")
    print("PREDICTIONS:")
    for app, prob in zip(top_3_apps, top_3_probs):
        print(f"   - {app:<25} (Confidence: {prob:.2%})")
    print(f"NEXT APP: {true_app_name}")
    print("="*60)
# Out:
# --- Running Test Predictions ---
# calendar | maps | facebook | maps | maps | hangouts | facebook | hangouts | calendar | google | hangouts | google | hangouts | maps | facebook
# PREDICTIONS:
#    - facebook                  (Confidence: 22.03%)
#    - google                    (Confidence: 18.53%)
#    - gmail                     (Confidence: 9.50%)
# NEXT APP: hangouts
# ============================================================
# calculator | google | calculator | google | calculator | calculator | snapchat | calculator | reddit | reddit | reddit | reddit | reddit | youtube | youtube
# PREDICTIONS:
#    - youtube                   (Confidence: 30.97%)
#    - google                    (Confidence: 22.70%)
#    - reddit                    (Confidence: 12.03%)
# NEXT APP: snapchat
# ============================================================
# <OOV> | facebook | <OOV> | <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV> | <OOV> | contacts | <OOV> | contacts | <OOV>
# PREDICTIONS:
#    - contacts                  (Confidence: 95.99%)
#    - facebook                  (Confidence: 1.80%)
#    - google                    (Confidence: 0.67%)
# NEXT APP: contacts
# ============================================================
# facebook | reddit | reddit | <OOV> | messages | <OOV> | messages | <OOV> | messages | <OOV> | calendar | reddit | <OOV> | reddit | messages
# PREDICTIONS:
#    - reddit                    (Confidence: 82.24%)
#    - offerup                   (Confidence: 5.54%)
#    - lucktastic                (Confidence: 3.94%)
# NEXT APP: reddit
# ============================================================
# youtube | messages | youtube | messages | <OOV> | messages | <OOV> | messages | <OOV> | messages | <OOV> | messages | <OOV> | messages | <OOV>
# PREDICTIONS:
#    - messages                  (Confidence: 98.43%)
#    - youtube                   (Confidence: 0.80%)
#    - google                    (Confidence: 0.17%)
# NEXT APP: messages
# ============================================================
# s’more | twitter | s’more | twitter | s’more | twitter | s’more | twitter | s’more | twitter | s’more | s’more | twitter | s’more | twitter
# PREDICTIONS:
#    - s’more                    (Confidence: 87.52%)
#    - youtube                   (Confidence: 4.33%)
#    - snapchat                  (Confidence: 1.65%)
# NEXT APP: s’more
# ============================================================
# phone | <OOV> | phone | <OOV> | phone | <OOV> | <OOV> | phone | phone | phone | settings | phone | settings | phone | metrozone
# PREDICTIONS:
#    - phone                     (Confidence: 95.61%)
#    - messaging                 (Confidence: 1.09%)
#    - gmail                     (Confidence: 0.99%)
# NEXT APP: phone
# ============================================================
# <OOV> | instagram | <OOV> | instagram | <OOV> | instagram | <OOV> | instagram | <OOV> | instagram | <OOV> | instagram | <OOV> | instagram | <OOV>
# PREDICTIONS:
#    - instagram                 (Confidence: 98.22%)
#    - google                    (Confidence: 1.11%)
#    - facebook                  (Confidence: 0.13%)
# NEXT APP: instagram
# ============================================================
# <OOV> | <OOV> | <OOV> | <OOV> | aol | <OOV> | aol | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | aol | <OOV> | <OOV>
# PREDICTIONS:
#    - aol                       (Confidence: 69.10%)
#    - facebook                  (Confidence: 18.35%)
#    - gmail                     (Confidence: 7.39%)
# NEXT APP: aol
# ============================================================
# contacts | <OOV> | contacts | messages | messages | contacts | messages | contacts | <OOV> | messages | <OOV> | messages | <OOV> | messages | <OOV>
# PREDICTIONS:
#    - messages                  (Confidence: 97.78%)
#    - contacts                  (Confidence: 0.59%)
#    - youtube                   (Confidence: 0.31%)
# NEXT APP: messages
# ============================================================
# google | <OOV> | <OOV> | calculator | google | <OOV> | <OOV> | camera | camera | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 46.14%)
#    - camera                    (Confidence: 33.77%)
#    - youtube                   (Confidence: 5.84%)
# NEXT APP: google
# ============================================================
# <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 18.31%)
#    - facebook                  (Confidence: 16.20%)
#    - settings                  (Confidence: 12.37%)
# NEXT APP: contacts
# ============================================================
# <OOV> | facebook | aol | facebook | aol | maps | gmail | facebook | gmail | <OOV> | facebook | aol | facebook | aol | <OOV>
# PREDICTIONS:
#    - aol                       (Confidence: 60.76%)
#    - facebook                  (Confidence: 28.76%)
#    - gmail                     (Confidence: 6.40%)
# NEXT APP: aol
# ============================================================
# contacts | phone | messaging | phone | phone | phone | phone | gmail | maps | phone | metrozone | phone | gmail | phone | gmail
# PREDICTIONS:
#    - phone                     (Confidence: 93.02%)
#    - maps                      (Confidence: 2.31%)
#    - google                    (Confidence: 1.93%)
# NEXT APP: phone
# ============================================================
# <OOV> | <OOV> | <OOV> | google | <OOV> | youtube | <OOV> | google | <OOV> | <OOV> | <OOV> | google | <OOV> | <OOV> | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 58.54%)
#    - youtube                   (Confidence: 15.35%)
#    - facebook                  (Confidence: 6.87%)
# NEXT APP: google
# ============================================================
# instagram | google | twitter | google | twitter | google | twitter | twitter | google | twitter | google | <OOV> | google | <OOV> | twitter
# PREDICTIONS:
#    - google                    (Confidence: 88.65%)
#    - gmail                     (Confidence: 2.26%)
#    - telegram                  (Confidence: 1.53%)
# NEXT APP: google
# ============================================================
# gmail | instagram | <OOV> | contacts | contacts | <OOV> | gmail | facebook | <OOV> | gmail | instagram | <OOV> | facebook | gmail | <OOV>
# PREDICTIONS:
#    - gmail                     (Confidence: 41.20%)
#    - facebook                  (Confidence: 29.00%)
#    - instagram                 (Confidence: 12.75%)
# NEXT APP: facebook
# ============================================================
# contacts | messages | contacts | contacts | messages | contacts | messages | contacts | messages | contacts | messages | contacts | messages | contacts | messages
# PREDICTIONS:
#    - contacts                  (Confidence: 99.73%)
#    - calculator                (Confidence: 0.07%)
#    - settings                  (Confidence: 0.05%)
# NEXT APP: contacts
# ============================================================
# <OOV> | <OOV> | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | contacts | <OOV> | google | contacts | google
# PREDICTIONS:
#    - contacts                  (Confidence: 96.41%)
#    - gmail                     (Confidence: 0.93%)
#    - maps                      (Confidence: 0.64%)
# NEXT APP: contacts
# ============================================================
# <OOV> | netflix | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | instagram | instagram
# PREDICTIONS:
#    - instagram                 (Confidence: 49.55%)
#    - netflix                   (Confidence: 6.73%)
#    - google                    (Confidence: 6.25%)
# NEXT APP: telegram
# ============================================================
# contacts | <OOV> | contacts | calendar | contacts | calendar | contacts | <OOV> | messages | <OOV> | contacts | messages | contacts | messages | contacts
# PREDICTIONS:
#    - messages                  (Confidence: 99.51%)
#    - google                    (Confidence: 0.21%)
#    - settings                  (Confidence: 0.07%)
# NEXT APP: messages
# ============================================================
# contacts | camera | <OOV> | camera | contacts | youtube | google | contacts | contacts | contacts | <OOV> | google | <OOV> | contacts | contacts
# PREDICTIONS:
#    - contacts                  (Confidence: 81.72%)
#    - messages                  (Confidence: 5.15%)
#    - google                    (Confidence: 4.54%)
# NEXT APP: contacts
# ============================================================
# netflix | gmail | google | netflix | gmail | google | netflix | telegram | netflix | telegram | netflix | telegram | telegram | netflix | telegram
# PREDICTIONS:
#    - netflix                   (Confidence: 82.51%)
#    - google                    (Confidence: 8.22%)
#    - gmail                     (Confidence: 5.72%)
# NEXT APP: netflix
# ============================================================
# <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.69%)
#    - gmail                     (Confidence: 0.06%)
#    - settings                  (Confidence: 0.04%)
# NEXT APP: google
# ============================================================
# <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.74%)
#    - gmail                     (Confidence: 0.05%)
#    - messages                  (Confidence: 0.03%)
# NEXT APP: google
# ============================================================
# <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV> | contacts | <OOV>
# PREDICTIONS:
#    - contacts                  (Confidence: 99.41%)
#    - gmail                     (Confidence: 0.12%)
#    - facebook                  (Confidence: 0.11%)
# NEXT APP: contacts
# ============================================================
# <OOV> | phone | <OOV> | phone | <OOV> | phone | <OOV> | phone | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | phone | <OOV>
# PREDICTIONS:
#    - phone                     (Confidence: 98.37%)
#    - google                    (Confidence: 0.74%)
#    - maps                      (Confidence: 0.22%)
# NEXT APP: phone
# ============================================================
# <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV> | twitter | <OOV> | telegram | twitter
# PREDICTIONS:
#    - telegram                  (Confidence: 97.65%)
#    - google                    (Confidence: 1.01%)
#    - instagram                 (Confidence: 0.63%)
# NEXT APP: telegram
# ============================================================
# facebook | telegram | instagram | telegram | google | <OOV> | google | <OOV> | instagram | <OOV> | maps | google | facebook | twitter | calendar
# PREDICTIONS:
#    - twitter                   (Confidence: 23.93%)
#    - instagram                 (Confidence: 16.76%)
#    - telegram                  (Confidence: 10.90%)
# NEXT APP: twitter
# ============================================================
# contacts | telegram | contacts | gmail | telegram | gmail | telegram | telegram | telegram | messages | telegram | messages | telegram | contacts | telegram
# PREDICTIONS:
#    - contacts                  (Confidence: 80.49%)
#    - messages                  (Confidence: 11.19%)
#    - gmail                     (Confidence: 5.54%)
# NEXT APP: messages
# ============================================================
# wechat | ebay | wechat | ebay | wechat | ebay | wechat | ebay | wechat | ebay | wechat | ebay | wechat | ebay | facebook
# PREDICTIONS:
#    - faceu                     (Confidence: 63.51%)
#    - wechat                    (Confidence: 22.97%)
#    - ebay                      (Confidence: 8.24%)
# NEXT APP: faceu
# ============================================================
# google | instagram | <OOV> | instagram | google | google | youtube | <OOV> | youtube | <OOV> | <OOV> | youtube | <OOV> | youtube | settings
# PREDICTIONS:
#    - youtube                   (Confidence: 87.17%)
#    - google                    (Confidence: 10.22%)
#    - instagram                 (Confidence: 0.64%)
# NEXT APP: google
# ============================================================
# instagram | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.25%)
#    - instagram                 (Confidence: 0.39%)
#    - maps                      (Confidence: 0.09%)
# NEXT APP: google
# ============================================================
# messages | contacts | messages | contacts | messages | contacts | messages | contacts | messages | contacts | messages | contacts | messages | facebook | messages
# PREDICTIONS:
#    - messages                  (Confidence: 47.95%)
#    - facebook                  (Confidence: 24.83%)
#    - contacts                  (Confidence: 10.52%)
# NEXT APP: messages
# ============================================================
# telegram | telegram | instagram | instagram | facebook | facebook | google | facebook | google | facebook | google | facebook | google | gmail | google
# PREDICTIONS:
#    - gmail                     (Confidence: 84.81%)
#    - instagram                 (Confidence: 7.09%)
#    - facebook                  (Confidence: 4.66%)
# NEXT APP: gmail
# ============================================================
# google | <OOV> | google | <OOV> | maps | <OOV> | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.43%)
#    - gmail                     (Confidence: 0.12%)
#    - settings                  (Confidence: 0.11%)
# NEXT APP: google
# ============================================================
# settings | gmail | settings | gmail | settings | gmail | settings | gmail | settings | gmail | settings | gmail | settings | gmail | settings
# PREDICTIONS:
#    - gmail                     (Confidence: 99.82%)
#    - google                    (Confidence: 0.06%)
#    - messages                  (Confidence: 0.05%)
# NEXT APP: gmail
# ============================================================
# instagram | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | messages | <OOV> | instagram
# PREDICTIONS:
#    - instagram                 (Confidence: 43.91%)
#    - messages                  (Confidence: 26.74%)
#    - facebook                  (Confidence: 6.58%)
# NEXT APP: instagram
# ============================================================
# telegram | settings | telegram | settings | telegram | youtube | telegram | youtube | telegram | youtube | youtube | telegram | telegram | youtube | telegram
# PREDICTIONS:
#    - youtube                   (Confidence: 92.17%)
#    - settings                  (Confidence: 7.31%)
#    - google                    (Confidence: 0.26%)
# NEXT APP: youtube
# ============================================================
# <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV>
# PREDICTIONS:
#    - facebook                  (Confidence: 99.33%)
#    - google                    (Confidence: 0.23%)
#    - messages                  (Confidence: 0.08%)
# NEXT APP: facebook
# ============================================================
# phone | gmail | settings | phone | settings | gmail | youtube | <OOV> | youtube | <OOV> | phone | metrozone | phone | metrozone | metrozone
# PREDICTIONS:
#    - metrozone                 (Confidence: 41.55%)
#    - phone                     (Confidence: 33.39%)
#    - messaging                 (Confidence: 8.68%)
# NEXT APP: gmail
# ============================================================
# gmail | messages | gmail | messages | gmail | messages | gmail | messages | gmail | messages | gmail | messages | gmail | messages | gmail
# PREDICTIONS:
#    - messages                  (Confidence: 98.84%)
#    - google                    (Confidence: 0.74%)
#    - youtube                   (Confidence: 0.07%)
# NEXT APP: messages
# ============================================================
# <OOV> | messages | facebook | messages | facebook | messages | facebook | messages | facebook | messages | facebook | messages | facebook | messages | facebook
# PREDICTIONS:
#    - messages                  (Confidence: 99.43%)
#    - google                    (Confidence: 0.15%)
#    - slidejoy                  (Confidence: 0.12%)
# NEXT APP: messages
# ============================================================
# gmail | twitter | s’more | s’more | s’more | s’more | s’more | s’more | s’more | s’more | s’more | s’more | s’more | s’more | twitter
# PREDICTIONS:
#    - s’more                    (Confidence: 56.83%)
#    - youtube                   (Confidence: 10.11%)
#    - gmail                     (Confidence: 5.17%)
# NEXT APP: instagram
# ============================================================
# facebook | <OOV> | facebook | <OOV> | discord | gmail | discord | gmail | <OOV> | gmail | <OOV> | facebook | <OOV> | facebook | gmail
# PREDICTIONS:
#    - facebook                  (Confidence: 92.52%)
#    - discord                   (Confidence: 4.59%)
#    - instagram                 (Confidence: 1.16%)
# NEXT APP: facebook
# ============================================================
# instagram | google | instagram | google | instagram | google | instagram | google | instagram | google | instagram | google | instagram | google | instagram
# PREDICTIONS:
#    - google                    (Confidence: 99.91%)
#    - gmail                     (Confidence: 0.02%)
#    - messages                  (Confidence: 0.02%)
# NEXT APP: google
# ============================================================
# <OOV> | <OOV> | <OOV> | <OOV> | messages | messages | <OOV> | facebook | slidejoy | <OOV> | slidejoy | slidejoy | <OOV> | slidejoy | <OOV>
# PREDICTIONS:
#    - slidejoy                  (Confidence: 94.43%)
#    - messages                  (Confidence: 2.84%)
#    - facebook                  (Confidence: 1.29%)
# NEXT APP: slidejoy
# ============================================================
# swagbucks | <OOV> | swagbucks | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | swagbucks
# PREDICTIONS:
#    - facebook                  (Confidence: 97.74%)
#    - google                    (Confidence: 1.17%)
#    - gmail                     (Confidence: 0.21%)
# NEXT APP: facebook
# ============================================================
# <OOV> | <OOV> | facebook | <OOV> | facebook | phone | facebook | <OOV> | messaging | facebook | google | settings | phone | facebook | phone
# PREDICTIONS:
#    - phone                     (Confidence: 50.10%)
#    - facebook                  (Confidence: 19.06%)
#    - gmail                     (Confidence: 6.44%)
# NEXT APP: google
# ============================================================
# phone | messaging | phone | messaging | phone | phone | messaging | phone | messaging | messaging | phone | gmail | phone | messaging | phone
# PREDICTIONS:
#    - messaging                 (Confidence: 87.37%)
#    - gmail                     (Confidence: 6.00%)
#    - contacts                  (Confidence: 4.96%)
# NEXT APP: messaging
# ============================================================
# contacts | phone | contacts | phone | contacts | phone | contacts | phone | contacts | phone | contacts | phone | contacts | phone | contacts
# PREDICTIONS:
#    - phone                     (Confidence: 98.34%)
#    - messaging                 (Confidence: 1.46%)
#    - google                    (Confidence: 0.09%)
# NEXT APP: phone
# ============================================================
# <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV> | gmail | <OOV>
# PREDICTIONS:
#    - gmail                     (Confidence: 99.32%)
#    - google                    (Confidence: 0.13%)
#    - messages                  (Confidence: 0.11%)
# NEXT APP: gmail
# ============================================================
# google | <OOV> | <OOV> | <OOV> | hangouts | <OOV> | <OOV> | hangouts | messages | <OOV> | <OOV> | <OOV> | google | hangouts | <OOV>
# PREDICTIONS:
#    - hangouts                  (Confidence: 51.00%)
#    - google                    (Confidence: 31.92%)
#    - instagram                 (Confidence: 5.67%)
# NEXT APP: google
# ============================================================
# <OOV> | metrozone | metrozone | settings | <OOV> | google | <OOV> | metrozone | contacts | metrozone | <OOV> | metrozone | contacts | <OOV> | contacts
# PREDICTIONS:
#    - metrozone                 (Confidence: 47.07%)
#    - contacts                  (Confidence: 27.00%)
#    - gmail                     (Confidence: 15.14%)
# NEXT APP: metrozone
# ============================================================
# twitter | youtube | twitter | youtube | google | youtube | twitter | youtube | twitter | youtube | twitter | youtube | twitter | youtube | twitter
# PREDICTIONS:
#    - youtube                   (Confidence: 97.78%)
#    - google                    (Confidence: 1.58%)
#    - gmail                     (Confidence: 0.10%)
# NEXT APP: youtube
# ============================================================
# google | youtube | google | youtube | google | youtube | google | youtube | google | youtube | google | youtube | google | youtube | google
# PREDICTIONS:
#    - youtube                   (Confidence: 68.43%)
#    - google                    (Confidence: 14.10%)
#    - instagram                 (Confidence: 4.21%)
# NEXT APP: youtube
# ============================================================
# google | instagram | google | instagram | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV> | facebook | <OOV>
# PREDICTIONS:
#    - facebook                  (Confidence: 96.97%)
#    - google                    (Confidence: 2.32%)
#    - instagram                 (Confidence: 0.38%)
# NEXT APP: facebook
# ============================================================
# <OOV> | maps | <OOV> | maps | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | instagram | <OOV> | instagram | <OOV>
# PREDICTIONS:
#    - instagram                 (Confidence: 68.43%)
#    - maps                      (Confidence: 7.64%)
#    - facebook                  (Confidence: 5.91%)
# NEXT APP: hangouts
# ============================================================
# facebook | maps | maps | <OOV> | facebook | <OOV> | facebook | gmail | maps | <OOV> | maps | <OOV> | maps | facebook | gmail
# PREDICTIONS:
#    - facebook                  (Confidence: 27.11%)
#    - gmail                     (Confidence: 19.29%)
#    - maps                      (Confidence: 11.80%)
# NEXT APP: gmail
# ============================================================
# google | <OOV> | google | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.77%)
#    - gmail                     (Confidence: 0.05%)
#    - messages                  (Confidence: 0.03%)
# NEXT APP: google
# ============================================================
# phone | google | google | google | phone | google | robinhood | google | phone | google | google | gmail | google | google | phone
# PREDICTIONS:
#    - google                    (Confidence: 39.77%)
#    - phone                     (Confidence: 24.59%)
#    - gmail                     (Confidence: 10.93%)
# NEXT APP: phone
# ============================================================
# gmail | gmail | google | maps | google | maps | gmail | phone | gmail | phone | messaging | phone | messaging | phone | metrozone
# PREDICTIONS:
#    - metrozone                 (Confidence: 76.82%)
#    - phone                     (Confidence: 14.51%)
#    - messaging                 (Confidence: 3.29%)
# NEXT APP: phone
# ============================================================
# instagram | phone | instagram | settings | instagram | clock | clock | clock | google | twitter | telegram | twitter | <OOV> | twitter | <OOV>
# PREDICTIONS:
#    - twitter                   (Confidence: 53.08%)
#    - instagram                 (Confidence: 14.26%)
#    - google                    (Confidence: 12.70%)
# NEXT APP: twitter
# ============================================================
# telegram | contacts | telegram | contacts | telegram | contacts | telegram | contacts | gmail | contacts | gmail | telegram | contacts | gmail | telegram
# PREDICTIONS:
#    - gmail                     (Confidence: 72.54%)
#    - contacts                  (Confidence: 16.74%)
#    - instagram                 (Confidence: 6.94%)
# NEXT APP: contacts
# ============================================================
# messages | instagram | messages | <OOV> | messages | <OOV> | camera | <OOV> | messages | <OOV> | messages | <OOV> | <OOV> | <OOV> | <OOV>
# PREDICTIONS:
#    - messages                  (Confidence: 38.25%)
#    - instagram                 (Confidence: 23.29%)
#    - camera                    (Confidence: 9.96%)
# NEXT APP: calculator
# ============================================================
# <OOV> | gmail | <OOV> | twitter | google | instagram | google | settings | google | <OOV> | google | <OOV> | google | telegram | google
# PREDICTIONS:
#    - telegram                  (Confidence: 85.93%)
#    - instagram                 (Confidence: 10.32%)
#    - twitter                   (Confidence: 1.05%)
# NEXT APP: instagram
# ============================================================
# <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 85.60%)
#    - facebook                  (Confidence: 3.43%)
#    - gmail                     (Confidence: 2.24%)
# NEXT APP: google
# ============================================================
# <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 99.70%)
#    - gmail                     (Confidence: 0.07%)
#    - settings                  (Confidence: 0.04%)
# NEXT APP: google
# ============================================================
# instagram | telegram | settings | <OOV> | telegram | instagram | twitter | instagram | telegram | twitter | telegram | gmail | telegram | telegram | instagram
# PREDICTIONS:
#    - telegram                  (Confidence: 43.25%)
#    - instagram                 (Confidence: 23.94%)
#    - twitter                   (Confidence: 13.57%)
# NEXT APP: telegram
# ============================================================
# instagram | <OOV> | instagram | <OOV> | instagram | <OOV> | instagram | <OOV> | instagram | <OOV> | instagram | instagram | google | instagram | google
# PREDICTIONS:
#    - instagram                 (Confidence: 98.99%)
#    - maps                      (Confidence: 0.22%)
#    - facebook                  (Confidence: 0.16%)
# NEXT APP: instagram
# ============================================================
# <OOV> | <OOV> | google | settings | google | snapchat | google | snapchat | google | maps | <OOV> | swagbucks | google | swagbucks | google
# PREDICTIONS:
#    - swagbucks                 (Confidence: 89.19%)
#    - snapchat                  (Confidence: 4.87%)
#    - settings                  (Confidence: 2.64%)
# NEXT APP: swagbucks
# ============================================================
# telegram | telegram | google | telegram | telegram | youtube | telegram | youtube | telegram | youtube | telegram | youtube | telegram | maps | telegram
# PREDICTIONS:
#    - maps                      (Confidence: 70.55%)
#    - youtube                   (Confidence: 12.35%)
#    - google                    (Confidence: 7.10%)
# NEXT APP: maps
# ============================================================
# <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | contacts | <OOV>
# PREDICTIONS:
#    - contacts                  (Confidence: 97.31%)
#    - google                    (Confidence: 0.62%)
#    - gmail                     (Confidence: 0.53%)
# NEXT APP: contacts
# ============================================================
# messages | slidejoy | messages | slidejoy | messages | slidejoy | messages | instagram | <OOV> | slidejoy | messages | instagram | <OOV> | messages | gmail
# PREDICTIONS:
#    - messages                  (Confidence: 88.30%)
#    - slidejoy                  (Confidence: 5.93%)
#    - instagram                 (Confidence: 3.11%)
# NEXT APP: messages
# ============================================================
# camera | instagram | <OOV> | instagram | <OOV> | instagram | <OOV> | instagram | <OOV> | gmail | <OOV> | instagram | instagram | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 81.11%)
#    - instagram                 (Confidence: 16.65%)
#    - facebook                  (Confidence: 0.41%)
# NEXT APP: google
# ============================================================
# twitter | google | <OOV> | contacts | messages | facebook | facebook | <OOV> | facebook | facebook | facebook | facebook | messages | facebook | messages
# PREDICTIONS:
#    - messages                  (Confidence: 52.93%)
#    - facebook                  (Confidence: 32.62%)
#    - google                    (Confidence: 4.63%)
# NEXT APP: messages
# ============================================================
# google | google | <OOV> | google | <OOV> | google | gmail | <OOV> | gmail | <OOV> | google | maps | google | maps | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 35.06%)
#    - maps                      (Confidence: 33.32%)
#    - gmail                     (Confidence: 15.61%)
# NEXT APP: maps
# ============================================================
# google | settings | google | settings | google | settings | google | google | google | google | google | gmail | google | gmail | google
# PREDICTIONS:
#    - gmail                     (Confidence: 95.88%)
#    - instagram                 (Confidence: 1.99%)
#    - settings                  (Confidence: 0.81%)
# NEXT APP: gmail
# ============================================================
# messages | <OOV> | messages | <OOV> | messages | <OOV> | <OOV> | messages | <OOV> | messages | <OOV> | messages | messages | <OOV> | messages
# PREDICTIONS:
#    - messages                  (Confidence: 72.72%)
#    - google                    (Confidence: 5.69%)
#    - facebook                  (Confidence: 5.33%)
# NEXT APP: messages
# ============================================================
# slidejoy | messages | slidejoy | messages | slidejoy | messages | slidejoy | messages | slidejoy | messages | <OOV> | messages | <OOV> | messages | <OOV>
# PREDICTIONS:
#    - messages                  (Confidence: 95.09%)
#    - slidejoy                  (Confidence: 3.41%)
#    - maps                      (Confidence: 0.48%)
# NEXT APP: messages
# ============================================================
# <OOV> | youtube | <OOV> | youtube | <OOV> | youtube | <OOV> | youtube | <OOV> | youtube | <OOV> | youtube | <OOV> | youtube | <OOV>
# PREDICTIONS:
#    - youtube                   (Confidence: 93.61%)
#    - google                    (Confidence: 1.41%)
#    - facebook                  (Confidence: 1.40%)
# NEXT APP: youtube
# ============================================================
# settings | <OOV> | settings | <OOV> | settings | <OOV> | settings | settings | <OOV> | settings | <OOV> | settings | <OOV> | settings | <OOV>
# PREDICTIONS:
#    - settings                  (Confidence: 99.60%)
#    - google                    (Confidence: 0.12%)
#    - gmail                     (Confidence: 0.07%)
# NEXT APP: settings
# ============================================================
# <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | instagram | google | facebook | instagram | google | instagram | gmail | google | instagram | gmail
# PREDICTIONS:
#    - instagram                 (Confidence: 68.54%)
#    - google                    (Confidence: 23.41%)
#    - facebook                  (Confidence: 5.51%)
# NEXT APP: google
# ============================================================
# facebook | <OOV> | facebook | google | facebook | messages | facebook | messages | facebook | messages | facebook | messages | facebook | messages | facebook
# PREDICTIONS:
#    - messages                  (Confidence: 99.53%)
#    - google                    (Confidence: 0.16%)
#    - slidejoy                  (Confidence: 0.10%)
# NEXT APP: messages
# ============================================================
# google | settings | google | settings | google | settings | google | settings | google | google | google | google | google | gmail | google
# PREDICTIONS:
#    - gmail                     (Confidence: 93.08%)
#    - instagram                 (Confidence: 2.79%)
#    - settings                  (Confidence: 2.20%)
# NEXT APP: gmail
# ============================================================
# google | instagram | google | instagram | <OOV> | instagram | google | instagram | google | <OOV> | google | telegram | google | telegram | <OOV>
# PREDICTIONS:
#    - telegram                  (Confidence: 81.52%)
#    - google                    (Confidence: 17.71%)
#    - instagram                 (Confidence: 0.25%)
# NEXT APP: google
# ============================================================
# phone | phone | google | maps | phone | maps | phone | maps | <OOV> | maps | <OOV> | maps | <OOV> | maps | <OOV>
# PREDICTIONS:
#    - maps                      (Confidence: 83.69%)
#    - google                    (Confidence: 4.43%)
#    - facebook                  (Confidence: 2.45%)
# NEXT APP: maps
# ============================================================
# <OOV> | <OOV> | <OOV> | <OOV> | walmart | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | walmart | <OOV> | walmart | <OOV>
# PREDICTIONS:
#    - walmart                   (Confidence: 99.74%)
#    - settings                  (Confidence: 0.09%)
#    - facebook                  (Confidence: 0.06%)
# NEXT APP: walmart
# ============================================================
# facebook | snapchat | facebook | snapchat | facebook | snapchat | instagram | snapchat | twitter | <OOV> | <OOV> | facebook | messages | camera | messages
# PREDICTIONS:
#    - twitter                   (Confidence: 24.88%)
#    - facebook                  (Confidence: 21.16%)
#    - snapchat                  (Confidence: 18.10%)
# NEXT APP: instagram
# ============================================================
# <OOV> | telegram | <OOV> | instagram | telegram | <OOV> | telegram | maps | telegram | <OOV> | instagram | calendar | <OOV> | google | <OOV>
# PREDICTIONS:
#    - telegram                  (Confidence: 27.68%)
#    - instagram                 (Confidence: 22.43%)
#    - google                    (Confidence: 18.30%)
# NEXT APP: google
# ============================================================
# instagram | google | google | instagram | google | <OOV> | google | <OOV> | google | instagram | google | instagram | google | google | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 85.25%)
#    - instagram                 (Confidence: 7.12%)
#    - gmail                     (Confidence: 2.37%)
# NEXT APP: google
# ============================================================
# contacts | phone | phone | contacts | phone | contacts | phone | contacts | phone | messaging | phone | messaging | phone | messaging | phone
# PREDICTIONS:
#    - messaging                 (Confidence: 38.91%)
#    - phone                     (Confidence: 19.60%)
#    - contacts                  (Confidence: 15.17%)
# NEXT APP: messaging
# ============================================================
# messages | faceu | messages | faceu | messages | faceu | messages | faceu | messages | messages | settings | faceu | faceu | <OOV> | youtube
# PREDICTIONS:
#    - messages                  (Confidence: 32.04%)
#    - settings                  (Confidence: 10.97%)
#    - faceu                     (Confidence: 10.68%)
# NEXT APP: faceu
# ============================================================
# swagbucks | google | swagbucks | google | swagbucks | google | swagbucks | google | swagbucks | google | swagbucks | google | swagbucks | google | swagbucks
# PREDICTIONS:
#    - google                    (Confidence: 99.79%)
#    - facebook                  (Confidence: 0.05%)
#    - messages                  (Confidence: 0.04%)
# NEXT APP: google
# ============================================================
# google | hangouts | google | youtube | google | youtube | google | youtube | google | <OOV> | google | <OOV> | youtube | hangouts | youtube
# PREDICTIONS:
#    - hangouts                  (Confidence: 40.41%)
#    - google                    (Confidence: 25.95%)
#    - youtube                   (Confidence: 14.04%)
# NEXT APP: youtube
# ============================================================
# <OOV> | <OOV> | reddit | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV> | <OOV>
# PREDICTIONS:
#    - reddit                    (Confidence: 24.12%)
#    - facebook                  (Confidence: 16.51%)
#    - settings                  (Confidence: 14.26%)
# NEXT APP: faceu
# ============================================================
# metrozone | metrozone | instagram | metrozone | instagram | metrozone | messaging | instagram | google | <OOV> | google | messaging | google | messaging | messaging
# PREDICTIONS:
#    - messaging                 (Confidence: 44.35%)
#    - phone                     (Confidence: 24.07%)
#    - google                    (Confidence: 6.83%)
# NEXT APP: phone
# ============================================================
# google | telegram | google | telegram | google | telegram | google | telegram | google | telegram | google | telegram | google | telegram | google
# PREDICTIONS:
#    - telegram                  (Confidence: 94.17%)
#    - instagram                 (Confidence: 5.09%)
#    - youtube                   (Confidence: 0.23%)
# NEXT APP: telegram
# ============================================================
# google | telegram | <OOV> | gmail | <OOV> | <OOV> | telegram | facebook | <OOV> | google | <OOV> | <OOV> | <OOV> | telegram | facebook
# PREDICTIONS:
#    - telegram                  (Confidence: 71.76%)
#    - google                    (Confidence: 12.96%)
#    - gmail                     (Confidence: 6.69%)
# NEXT APP: telegram
# ============================================================
# google | <OOV> | google | <OOV> | calculator | camera | google | <OOV> | google | <OOV> | google | <OOV> | google | <OOV> | <OOV>
# PREDICTIONS:
#    - google                    (Confidence: 80.37%)
#    - camera                    (Confidence: 10.99%)
#    - facebook                  (Confidence: 1.79%)
# NEXT APP: google
# ============================================================

# %%
# Calculate how many times the true label is in the top-3 predictions
from tqdm import tqdm

top3_correct = 0
top1_correct = 0
N = min(len(X_test_seq), 1000)
mistakes = []

for i in tqdm(range(N), desc="Evaluating top-3 accuracy"):
    input_sequence_tokens = X_test_seq[i]
    input_extra_features = X_test_extra[i]
    true_label_token = np.argmax(y_test[i])

    input_seq_batch = np.expand_dims(input_sequence_tokens, axis=0)
    input_extra_batch = np.expand_dims(input_extra_features, axis=0)

    prediction_proba = model.predict([input_seq_batch, input_extra_batch], verbose=0)[0]
    
    if oov_index is not None and oov_index < len(prediction_proba):
        prediction_proba[oov_index] = 0

    top_3_indices = np.argsort(prediction_proba)[-3:][::-1]
    if true_label_token in top_3_indices:
        top3_correct += 1
    else:
        # Save mistake info
        input_app_names = [reverse_word_index.get(token, '?') for token in input_sequence_tokens if token != 0]
        true_app_name = reverse_word_index.get(true_label_token, 'unknown')
        top_3_apps = [reverse_word_index.get(idx, 'unknown') for idx in top_3_indices]
        top_3_probs = [prediction_proba[idx] for idx in top_3_indices]
        mistake_str = (
            f"INPUT: {' | '.join(input_app_names)}\n"
            f"TRUE NEXT APP: {true_app_name}\n"
            f"PREDICTIONS:\n"
            + "\n".join([f"   - {app:<25} (Confidence: {prob:.2%})" for app, prob in zip(top_3_apps, top_3_probs)])
            + "\n" + "="*60 + "\n"
        )
        mistakes.append(mistake_str)
    if true_label_token == top_3_indices[0]:
        top1_correct += 1

top3_accuracy = top3_correct / N
top1_accuracy = top1_correct / N
print(f"Top-3 accuracy: {top3_accuracy:.2%} ({top3_correct}/{N})")
print(f"Top-1 accuracy: {top1_accuracy:.2%} ({top1_correct}/{N})")

# Save mistakes to file.txt
with open("mistakes.txt", "w", encoding="utf-8") as f:
    for mistake in mistakes:
        f.write(mistake)
# Out:
# Evaluating top-3 accuracy: 100%|██████████| 1000/1000 [00:29<00:00, 33.59it/s]
# Top-3 accuracy: 90.60% (906/1000)
# Top-1 accuracy: 76.70% (767/1000)
